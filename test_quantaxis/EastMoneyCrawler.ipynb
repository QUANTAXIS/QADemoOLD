# %%
import QUANTAXIS as QA

# %%
## 下面是东方财务通财务分析的爬虫

# %%
data=QA.QAFetch.QAEastMoney.QA_fetch_get_stock_analysis('600010')

# %%
data[0]
# Out:
#                                                   ms    rq
# 0  生产、销售:黑色金属及其延压加工产品、冶金机械、设备及配件,焦炭及焦化副产品(化工)生产和销...  none

# %%
data[1]
# Out:
#        gpdm                                                 ms  \
# 0  60001001  2017年以来,公司坚持稳中求进总基调,以“降本增效”为抓手,积极应对市场变化,保持生产经营...
#
#                   rq
# 0  2017/6/30 0:00:00

# %%
data[2]
# Out:
#                         cbbl dw     lrbl      mll       orderby          rq  \
# date       classify
# 2016-12-31 hy         98.60%  元  100.07%    8.72%  3.063367e+10  2016-12-31
#            hy          1.40%  元   -0.07%   -0.49%  3.945096e+08  2016-12-31
#            cp         50.92%  元   38.49%    6.64%  1.546645e+10  2016-12-31
#            cp         20.67%  元   34.65%   13.63%  6.786366e+09  2016-12-31
#            cp         12.74%  元  -10.83%   -8.70%  3.322457e+09  2016-12-31
#            cp          7.96%  元   33.56%   28.40%  3.153979e+09  2016-12-31
#            cp          7.72%  元    4.13%    4.80%  2.298927e+09  2016-12-31
#            qy         52.15%  元   45.07%    7.52%  1.599290e+10  2016-12-31
#            qy         18.59%  元   23.21%   10.52%  5.891463e+09  2016-12-31
#            qy         12.02%  元   12.14%    8.68%  3.732813e+09  2016-12-31
#            qy          7.06%  元   10.66%   12.44%  2.287516e+09  2016-12-31
# ...
