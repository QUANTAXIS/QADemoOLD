# %%
# block analysis

# %%
import QUANTAXIS as QA
# Out:
# QUANTAXIS>> start QUANTAXIS
# QUANTAXIS>> Selecting the Best Server IP of TDX
# Bad REPSONSE 180.153.18.17
# Bad REPSONSE sztdx.gtjas.com
# QUANTAXIS>> === The BEST SERVER ===
#  stock_ip 115.238.56.198 future_ip 61.152.107.141
# QUANTAXIS>> Welcome to QUANTAXIS, the Version is 1.0.14
# QUANTAXIS>>
#  ````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````
#   ``########`````##````````##``````````##`````````####````````##```##########````````#``````##``````###```##`````######``
#   `##``````## ```##````````##`````````####````````##`##```````##```````##```````````###``````##````##`````##```##`````##`
#   ##````````##```##````````##````````##`##````````##``##``````##```````##``````````####```````#```##``````##```##``````##
#   ##````````##```##````````##```````##```##```````##```##`````##```````##`````````##`##```````##`##```````##````##```````
# ...

# %%
import re

# %%
B=QA.QA_fetch_stock_block_adv('600637')

# %%
B.block_name
# Out:
# ['300非周',
#  'IP变现',
#  'MSCI成份',
#  '三网融合',
#  '上海自贸',
#  '上证180',
#  '上证中盘',
#  '中证100',
#  '中证龙头',
#  '中金消费',
#  '国证服务',
#  '大数据i',
#  '大盘股',
#  '智能电视',
#  '梧桐持股',
#  '沪深300',
#  '网络游戏',
#  '虚拟现实',
#  '融资融券',
#  '行业龙头',
#  '证金持股',
#  '银河99',
#  '长三角']
